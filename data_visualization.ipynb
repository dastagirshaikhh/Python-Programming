# %%
from itertools import groupby
import pandas as pd
import os
# Setting the working directory
os.chdir("C:\\Users\\dasta\\OneDrive\\Documents\\Data Science Tabular sheets")
df = pd.read_csv("Car_sales.csv")  # Displaying the data

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df
# Out:
#       Manufacturer              Model  Sales in thousands  \
# 0       Mitsubishi  3000GT                          0.110
# 1            Dodge  Viper                           0.916
# 2    Mercedes-Benz  CL500                           0.954
# 3       Oldsmobile  Cutlass                         1.112
# 4          Porsche  Carrera Coupe                   1.280
# ..             ...                ...                 ...
# 152          Honda  Accord                        230.902
# 153           Ford  Taurus                        245.815
# 154         Toyota  Camry                         247.994
# 155           Ford  Explorer                      276.747
# 156           Ford  F-Series                      540.561
#
#      4-year resale value Vehicle type  Price in thousands  Engine size  \
# 0              20.940000    Passenger              25.450          3.0
# 1              58.470000    Passenger              69.725          8.0
# ...

# %%
for group, data in df.groupby('Manufacturer'):
    print (group, data['4-year resale value'].mean()) #printing the mean value of a column by grouping columns
# Out:
# Acura 21.04625
# Audi 28.27
# BMW 27.624325069999998
# Buick 14.94125
# Cadillac 22.329595042
# Chevrolet 13.768663912222221
# Chrysler 15.406139315714285
# Dodge 16.961634110000002
# Ford 13.424815928181818
# Honda 15.556999999999999
# Hyundai 7.531666666666666
# Infiniti 19.69
# Jaguar 18.07297521
# Jeep 15.353333333333333
# Lexus 25.607320938333334
# Lincoln 20.107658403333335
# Mercedes-Benz 29.648875116666666
# Mercury 13.969999999999999
# Mitsubishi 14.262142857142857
# Nissan 14.886564345714286
# Oldsmobile 17.073491736666664
# Plymouth 11.9119938025
# Pontiac 14.532162534999998
# Porsche 56.475
# Saab 18.07297521
# Saturn 13.345190084
# Subaru 18.07297521
# Toyota 16.814775023333336
# Volkswagen 14.966329201666666
# Volvo 18.07297521

# %%
#Displaying the data in the form of Horizontal Bar Graph
plt.figure(figsize=(25,8))
for group, data in df.groupby('Manufacturer'):
    plt.barh(group, data['4-year resale value'].mean()) #Displays the data in pie chart using matplotlib
    plt.xlabel ("4 Year resale value Average")
    plt.ylabel ("Manufacturer")
    plt.title ("4 Year resale Average value vs Manufacturer Graph")

# %%
dict1 = dict()
for items in set(df["Vehicle type"]):
    dict1[items] = df[df["Vehicle type"]==items].Manufacturer.count()

# %%
dict1
# Out:
# {'Passenger': 116, 'Car': 41}

# %%
plt.bar(dict1.keys(),dict1.values())
# Out:
# <BarContainer object of 2 artists>

# %%
plt.pie(dict1.values(), labels=dict1.keys()) #displays the data in pie chart using matplotlib
plt.show() #To remove the code displayed above the pie chart

# %%
plt.hist(df["Fuel efficiency"]) #Displays the data in hostogram using matplotlib
plt.show()

# %%
plt.scatter(df["Fuel efficiency"],df["Fuel capacity"]) #Displays the data in scatter plot using matplotlib
plt.show()

# %%
sns.distplot(df["Fuel efficiency"]) #Displays the data in bar graph using matplotlib
# Out:
# C:\Users\dasta\AppData\Local\Temp\ipykernel_11284\3228884011.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Fuel efficiency"]) #Displays the data in bar graph using matplotlib
# <AxesSubplot:xlabel='Fuel efficiency', ylabel='Density'>

# %%
#The line shown in the above graph shows the probability distribution and it can be removed using kde=False
sns.distplot(df["Fuel efficiency"],kde=False)
# Out:
# C:\Users\dasta\AppData\Local\Temp\ipykernel_11284\666719104.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Fuel efficiency"],kde=False)
# <AxesSubplot:xlabel='Fuel efficiency'>

# %%
sns.lmplot(data = df, x="Fuel capacity", y = "Fuel efficiency") #Displays the data in Scattered plot (Linear Modal plot) using matplotlib
#lmplot(Linear Modal plot) : Scattered plot

# %%
#To remove the line from the above Linear modal plot we can use fit_reg=False
sns.lmplot(data = df, x = "Fuel capacity", y = "Fuel efficiency",fit_reg=False)

# %%
sns.lmplot(
    data = df, x = "Fuel capacity",
    y = "Fuel efficiency",
    hue = "Vehicle type", #gives color to the scattered dots of the graph
    col = "Vehicle type", #Splits the graphs according to the type
    fit_reg=False)

# %%
sns.jointplot(data=df, x = "Fuel capacity", y = "Fuel efficiency")
#combines the plot and displays the data on graphical as well as in scattered plot

# %%
sns.barplot(data = df, x = "Vehicle type", y = "4-year resale value") #displays the data in the form of barplot
# Out:
# <AxesSubplot:xlabel='Vehicle type', ylabel='4-year resale value'>

# %%
sns.barplot(data = df, y = "Vehicle type", x = "4-year resale value") #works same as the above but after changing x with y and y with x it displays the graph horizontally
# Out:
# <AxesSubplot:xlabel='4-year resale value', ylabel='Vehicle type'>

# %%
sns.stripplot(data = df, y = "Vehicle type", x = "4-year resale value", hue = "4-year resale value")
# Out:
# <AxesSubplot:xlabel='4-year resale value', ylabel='Vehicle type'>

# %%
#Multiple variate plot
sns.pairplot(df[["Price in thousands", "4-year resale value", "Horsepower", "Fuel capacity", "Fuel efficiency"]])

# %%
df[["Price in thousands", "4-year resale value", "Horsepower", "Fuel capacity", "Fuel efficiency"]].corr()
#diaplays the outliers from the graph
# Out:
#                      Price in thousands  4-year resale value  Horsepower  \
# Price in thousands             1.000000             0.822452    0.839744
# 4-year resale value            0.822452             1.000000    0.696888
# Horsepower                     0.839744             0.696888    1.000000
# Fuel capacity                  0.423282             0.275045    0.499907
# Fuel efficiency               -0.492157            -0.358546   -0.611332
#
#                      Fuel capacity  Fuel efficiency
# Price in thousands        0.423282        -0.492157
# 4-year resale value       0.275045        -0.358546
# Horsepower                0.499907        -0.611332
# Fuel capacity             1.000000        -0.801512
# Fuel efficiency          -0.801512         1.000000

# %%
sns.heatmap(df[["Price in thousands", "4-year resale value", "Horsepower", "Fuel capacity", "Fuel efficiency"]].corr(), annot=True)
#in this type of plot lighter the colors are higher the value darker the colors lower the values like example below
#in the above logic annot=True is used to display the numbers in the plot
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(data = df, y = "Vehicle type", x = "Fuel efficiency") #box plot

#What is the use of line in the box?
# The line in the box plot works as a graph suppose there is a class of 65 students and each of them are owns a laptop
# 52 students owns laptops in the range of 30k to 70k and 8 students own laptops above 70k. So the median of 65 students
# is 33 if the line in the box follows the median and if the value in the right side of the median is higher than the 
# line in the box will appear on the right side and if the values are higher on the left side then the line in the box
# will appear on the left side.
# Out:
# <AxesSubplot:xlabel='Fuel efficiency', ylabel='Vehicle type'>
